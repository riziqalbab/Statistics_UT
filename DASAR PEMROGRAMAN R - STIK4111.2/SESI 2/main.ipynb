# %% [markdown]
# ## Diskusi 2

# %% [markdown]
# - NAMA : RIZIQ LILI ULI ALBAB
# - NIM : 058487469

# %% [markdown]
# ## PERTANYAAN 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a <- 5:10
b <- seq(10, 2, by = -2)
c <- seq(0, 1, by = 0.2)
d <- rep(c(3, 7, 9), times = c(3, 3, 2))
e <- rep(c(1, 2), times = 4)

# %% [markdown]
# ## PERTANYAAN 2

# %% [markdown]
# ![2026-04-21_22-00-01.png](attachment:2026-04-21_22-00-01.png)

# %%
df <- expand.grid(
  jurusan = c("Statistika", "Matematika", "Fisika"),
  kota = c("Jakarta", "Bandung", "Surabaya"),
  angkatan = 2021:2024
)

# %%
df
# Out:
#    jurusan    kota     angkatan
# 1  Statistika Jakarta  2021
# 2  Matematika Jakarta  2021
# 3  Fisika     Jakarta  2021
# 4  Statistika Bandung  2021
# 5  Matematika Bandung  2021
# 6  Fisika     Bandung  2021
# 7  Statistika Surabaya 2021
# 8  Matematika Surabaya 2021
# 9  Fisika     Surabaya 2021
# 10 Statistika Jakarta  2022
# 11 Matematika Jakarta  2022
# 12 Fisika     Jakarta  2022
# 13 Statistika Bandung  2022
# 14 Matematika Bandung  2022
# 15 Fisika     Bandung  2022
# 16 Statistika Surabaya 2022
# 17 Matematika Surabaya 2022
# 18 Fisika     Surabaya 2022
# 19 Statistika Jakarta  2023
# 20 Matematika Jakarta  2023
# 21 Fisika     Jakarta  2023
# 22 Statistika Bandung  2023
# 23 Matematika Bandung  2023
# 24 Fisika     Bandung  2023
# 25 Statistika Surabaya 2023
# 26 Matematika Surabaya 2023
# 27 Fisika     Surabaya 2023
# 28 Statistika Jakarta  2024
# 29 Matematika Jakarta  2024
# 30 Fisika     Jakarta  2024
# 31 Statistika Bandung  2024
# 32 Matematika Bandung  2024
# ...

# %% [markdown]
# ## PERTANYAAN 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nama <- c("Andi", "Budi", "Salwa", "Tono", "Siti")
umur <- c(20, 21, 19, 22, 20)

data <- data.frame(nama, umur)

# %%
data
# Out:
#   nama  umur
# 1 Andi  20
# 2 Budi  21
# 3 Salwa 19
# 4 Tono  22
# 5 Siti  20
