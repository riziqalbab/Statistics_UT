# %% [markdown]
# <div align="center">
#
# # TUGAS
# ## DASAR PEMROGRAMAN R
#
# </div>

# %% [markdown]
# ### NOMOR 1

# %%
for (i in 1:25) {
  if(x %% 2 == 1){
    print(x)
  }
}
# Out:
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25
# [1] 25

# %% [markdown]
# ### NOMOR 2

# %%
v <- rnorm(20)

for (i in 1:5) {
  hasil <- v[i] * v[i]
  
  cat(v[i], "x", v[i], "=", hasil, "\n")
}
# Out:
# 0.9759861 x 0.9759861 = 0.9525489
# -1.185611 x -1.185611 = 1.405673
# -0.6927477 x -0.6927477 = 0.4798994
# -1.300752 x -1.300752 = 1.691955
# -0.2283024 x -0.2283024 = 0.05212198

# %% [markdown]
# ### NOMOR 3

# %%
random_data <- rnorm(30)
mean_value <- mean(random_data)
cat("Rata-rata dari data acak adalah:", mean_value, "\n")

plot(random_data, main="Plot Data Acak", xlab="Indeks", ylab="Nilai Acak", pch=19, col="blue")
# Out:
# Rata-rata dari data acak adalah: 0.09096763
# Plot with title “Plot Data Acak”
